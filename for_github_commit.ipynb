# %%
cd /content/drive/MyDrive/Colab Notebooks/kaggle
# Out:
# /content/drive/MyDrive/Colab Notebooks/kaggle

# %%
# !echo "# kaggle-bike-sharing" >> README.md
# !git init
# !git config --global user.email "jumi.lee106@gmail.com"
# !git config --global user.name "itchyfeet-patient"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M master
# !git remote add origin https://itchyfeet-patient:xhrl5252@github.com/itchyfeet-patient/kaggle-BikeSharingDemand.git
# !git push -u origin master
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/kaggle/.git/
# [main 1d4d5fe] first commit
#  1 file changed, 1 insertion(+)
# fatal: remote origin already exists.
# remote: Support for password authentication was removed on August 13, 2021. Please use a personal access token instead.
# remote: Please see https://github.blog/2020-12-15-token-authentication-requirements-for-git-operations/ for more information.
# fatal: Authentication failed for 'https://itchyfeet-patient:xhrl5252@github.com/itchyfeet-patient/kaggle-BikeSharingDemand.git/'

# %%
# !git add .
# !git commit -m "setup"
# !git push --set-upstream origin master
# Out:
# On branch master
# nothing to commit, working tree clean
# remote: Support for password authentication was removed on August 13, 2021. Please use a personal access token instead.
# remote: Please see https://github.blog/2020-12-15-token-authentication-requirements-for-git-operations/ for more information.
# fatal: Authentication failed for 'https://itchyfeet-patient:xhrl5252@github.com/itchyfeet-patient/kaggle-BikeSharingDemand.git/'

# %% [markdown]
#  혹시 여기서 remote에서 잘못입력하셔서 fetal에러가 나시는 분은
#
# !git remote rm origin
# 이거 해주시면 remote다시 설정하실 수 있습니다.
